# %%
import numpy as np
sports = ['Cricket', 'Football', 'Tennis', 'Golf', 'Baseball']
sports_new = np.array(sports)
print(sports_new)
# Out:
# ['Cricket' 'Football' 'Tennis' 'Golf' 'Baseball']

# %%
np.arange(0, 20,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18])

# %%
np.linspace(10,20,10)
# Out:
# array([10.        , 11.11111111, 12.22222222, 13.33333333, 14.44444444,
#        15.55555556, 16.66666667, 17.77777778, 18.88888889, 20.        ])

# %%
a = np.array([[1,2],[3,4]])

# %%
np.transpose(a
             )
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
vec1 = np.array([4, 7, 8, 9, 10, 6, 1])
vec1[vec1>6] = 2
print(vec1)
# Out:
# [4 2 2 2 2 6 1]

# %%
import numpy as np
matrix = np.arange(1,10).reshape(3,3)
matrix[0:2,1:2] = 0
print(matrix)
# Out:
# [[1 0 3]
#  [4 0 6]
#  [7 8 9]]

# %%
import numpy as np
demo_matrix = np.array(([13,35,74,48], [23,37,37,38],[73,32,93,39]))
demo_matrix[2,3]
# Out:
# 39

# %%
import pandas as pd
s1 = pd.Series(['a', 'b'])
s2 = pd.Series(['c', 'd'])

# %%
pd.concat([s1,s2])
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
import numpy as np
demo_array = np.arange(10,17)
demo_array [:]= 101
demo_array
# Out:
# array([101, 101, 101, 101, 101, 101, 101])

# %%
import pandas as pd
score = [10, 15, 20, 25]
pd.Series(data=score, index = ['a','b','c','d'])
# Out:
# a    10
# b    15
# c    20
# d    25
# dtype: int64

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      --------------- ---------------------- 122.9/293.3 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\rers9\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\rers9\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas
import seaborn as sns
data=sns.load_dataset('tips')

# %%
pd.pivot_table(data=data, values='total_bill', index='sex', columns='day', aggfunc='mean')
# Out:
# day          Thur        Fri        Sat        Sun
# sex
# Male    18.714667  19.857000  20.802542  21.887241
# Female  16.715312  14.145556  19.680357  19.872222

# %%
pandas.pivot_table(data=data, values='total_bill', index='day', columns='sex', aggfunc='mean')
# Out:
# sex        Male     Female
# day
# Thur  18.714667  16.715312
# Fri   19.857000  14.145556
# Sat   20.802542  19.680357
# Sun   21.887241  19.872222

# %%
pandas.pivot_table(data=data, values='day', index='sex', columns='total_bill', aggfunc='mean')
# Out:
# C:\Users\rers9\AppData\Local\Temp\ipykernel_15724\2585661749.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pandas.pivot_table(data=data, values='day', index='sex', columns='total_bill', aggfunc='mean')
# Empty DataFrame
# Columns: []
# Index: [Male, Female]
